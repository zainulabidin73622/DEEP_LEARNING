# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, optimizers, utils, datasets, callbacks, preprocessing

# %%
# Constants
NUM_CLASSES = 10
EPOCHS = 50
BATCH_SIZE = 6

# %%
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %% [markdown]
#  **1B. Preprocessing the CIFAR-10 Dataset**

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

y_train = utils.to_categorical(y_train, NUM_CLASSES)
y_test = utils.to_categorical(y_test, NUM_CLASSES)

# %% [markdown]
# 2. **Build the model**

# %%
def residual_block(x, filters):
    shortcut = x
    if x.shape[-1] != filters:
        shortcut = layers.Conv2D(filters, 1, padding='same')(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Conv2D(filters, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)

    x = layers.Conv2D(filters, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)

    x = layers.Add()([shortcut, x])
    x = layers.LeakyReLU()(x)
    return x


input_layer = layers.Input((32, 32, 3))

x = layers.Conv2D(64, 3, padding="same")(input_layer)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)

x = residual_block(x, 64)
x = layers.MaxPooling2D()(x)

x = residual_block(x, 128)
x = layers.MaxPooling2D()(x)

x = residual_block(x, 256)
x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Dropout(0.5)(x)

x = layers.Dense(NUM_CLASSES, activation='softmax')(x)

model = models.Model(inputs=input_layer, outputs=x)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7       │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 32, 32,    │      1,792 │ input_layer_7[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_28      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 32, 32,    │     36,928 │ leaky_re_lu_28[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_29      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 32, 32,    │     36,928 │ leaky_re_lu_29[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_28[0… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_30      │ (None, 32, 32,    │          0 │ add_14[0][0]      │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 16, 16,    │          0 │ leaky_re_lu_30[0… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 16, 16,    │     73,856 │ max_pooling2d_7[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_31      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 16, 16,    │      8,320 │ max_pooling2d_7[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 16, 16,    │    147,584 │ leaky_re_lu_31[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_32      │ (None, 16, 16,    │          0 │ add_15[0][0]      │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 8, 8, 128) │          0 │ leaky_re_lu_32[0… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 8, 8, 256) │    295,168 │ max_pooling2d_8[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_33      │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 8, 8, 256) │     33,024 │ max_pooling2d_8[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ leaky_re_lu_33[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_34      │ (None, 8, 8, 256) │          0 │ add_16[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ leaky_re_lu_34[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │     65,792 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_35      │ (None, 256)       │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ leaky_re_lu_35[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 10)        │      2,570 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,298,442 (4.95 MB)
#  Trainable params: 1,295,242 (4.94 MB)
#  Non-trainable params: 3,200 (12.50 KB)

# %% [markdown]
# 3a. **Compile the model**

# %%
opt = optimizers.Adam(learning_rate=0.001)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

# %% [markdown]
# 3b. **Train the model**

# %%
lr_reduce = callbacks.ReduceLROnPlateau(monitor='val_accuracy', patience=5, factor=0.5, verbose=1)
early_stop = callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)

# Train
history = model.fit(
    datagen.flow(x_train, y_train, batch_size=BATCH_SIZE),
    validation_data=(x_test, y_test),
    steps_per_epoch=len(x_train) // BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=[lr_reduce, early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 57s 56ms/step - accuracy: 0.7639 - loss: 0.7010 - val_accuracy: 0.6809 - val_loss: 1.0461 - learning_rate: 0.0010
# Epoch 2/50
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 25s 33ms/step - accuracy: 0.7656 - loss: 0.7134
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7656 - loss: 0.7134 - val_accuracy: 0.6554 - val_loss: 1.1787 - learning_rate: 0.0010
# Epoch 3/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 36s 47ms/step - accuracy: 0.7852 - loss: 0.6279 - val_accuracy: 0.7818 - val_loss: 0.6875 - learning_rate: 0.0010
# Epoch 4/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8438 - loss: 0.6632 - val_accuracy: 0.7766 - val_loss: 0.7077 - learning_rate: 0.0010
# Epoch 5/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.7915 - loss: 0.5999 - val_accuracy: 0.8051 - val_loss: 0.5794 - learning_rate: 0.0010
# Epoch 6/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.4057 - val_accuracy: 0.8054 - val_loss: 0.5763 - learning_rate: 0.0010
# Epoch 7/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 39s 46ms/step - accuracy: 0.8018 - loss: 0.5751 - val_accuracy: 0.7899 - val_loss: 0.6479 - learning_rate: 0.0010
# Epoch 8/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8438 - loss: 0.4325 - val_accuracy: 0.7804 - val_loss: 0.6818 - learning_rate: 0.0010
# Epoch 9/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8147 - loss: 0.5489 - val_accuracy: 0.8013 - val_loss: 0.6090 - learning_rate: 0.0010
# Epoch 10/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8281 - loss: 0.5344 - val_accuracy: 0.8072 - val_loss: 0.5934 - learning_rate: 0.0010
# Epoch 11/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.8161 - loss: 0.5316 - val_accuracy: 0.8336 - val_loss: 0.5142 - learning_rate: 0.0010
# Epoch 12/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8281 - loss: 0.4053 - val_accuracy: 0.8347 - val_loss: 0.5036 - learning_rate: 0.0010
# Epoch 13/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.8311 - loss: 0.4989 - val_accuracy: 0.8071 - val_loss: 0.5849 - learning_rate: 0.0010
# Epoch 14/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8281 - loss: 0.4633 - val_accuracy: 0.8025 - val_loss: 0.6018 - learning_rate: 0.0010
# Epoch 15/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 78s 47ms/step - accuracy: 0.8293 - loss: 0.4939 - val_accuracy: 0.7679 - val_loss: 0.7595 - learning_rate: 0.0010
# Epoch 16/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7500 - loss: 0.5308 - val_accuracy: 0.7678 - val_loss: 0.7502 - learning_rate: 0.0010
# Epoch 17/50
# 780/781 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8332 - loss: 0.4852
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.8332 - loss: 0.4852 - val_accuracy: 0.7968 - val_loss: 0.6020 - learning_rate: 0.0010
# Epoch 18/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7188 - loss: 0.7092 - val_accuracy: 0.7985 - val_loss: 0.5988 - learning_rate: 5.0000e-04
# Epoch 19/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8549 - loss: 0.4155 - val_accuracy: 0.8474 - val_loss: 0.4470 - learning_rate: 5.0000e-04
# Epoch 20/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8125 - loss: 0.4617 - val_accuracy: 0.8468 - val_loss: 0.4485 - learning_rate: 5.0000e-04
# Epoch 21/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 45ms/step - accuracy: 0.8656 - loss: 0.3913 - val_accuracy: 0.8298 - val_loss: 0.5106 - learning_rate: 5.0000e-04
# Epoch 22/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9062 - loss: 0.3489 - val_accuracy: 0.8307 - val_loss: 0.5081 - learning_rate: 5.0000e-04
# Epoch 23/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 39s 46ms/step - accuracy: 0.8684 - loss: 0.3843 - val_accuracy: 0.8516 - val_loss: 0.4504 - learning_rate: 5.0000e-04
# Epoch 24/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.3401 - val_accuracy: 0.8523 - val_loss: 0.4484 - learning_rate: 5.0000e-04
# Epoch 25/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 46ms/step - accuracy: 0.8748 - loss: 0.3678 - val_accuracy: 0.8514 - val_loss: 0.4522 - learning_rate: 5.0000e-04
# Epoch 26/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8750 - loss: 0.3389 - val_accuracy: 0.8506 - val_loss: 0.4528 - learning_rate: 5.0000e-04
# Epoch 27/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.8778 - loss: 0.3526 - val_accuracy: 0.8399 - val_loss: 0.4836 - learning_rate: 5.0000e-04
# Epoch 28/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9219 - loss: 0.3144 - val_accuracy: 0.8394 - val_loss: 0.4872 - learning_rate: 5.0000e-04
# Epoch 29/50
# 780/781 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8763 - loss: 0.3568
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.8763 - loss: 0.3568 - val_accuracy: 0.8436 - val_loss: 0.4921 - learning_rate: 5.0000e-04
# Epoch 30/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9219 - loss: 0.2423 - val_accuracy: 0.8443 - val_loss: 0.4877 - learning_rate: 2.5000e-04
# Epoch 31/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.8893 - loss: 0.3233 - val_accuracy: 0.8678 - val_loss: 0.3921 - learning_rate: 2.5000e-04
# Epoch 32/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9062 - loss: 0.3207 - val_accuracy: 0.8678 - val_loss: 0.3921 - learning_rate: 2.5000e-04
# Epoch 33/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 44ms/step - accuracy: 0.8908 - loss: 0.3161 - val_accuracy: 0.8604 - val_loss: 0.4266 - learning_rate: 2.5000e-04
# Epoch 34/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8594 - loss: 0.3994 - val_accuracy: 0.8608 - val_loss: 0.4240 - learning_rate: 2.5000e-04
# Epoch 35/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8964 - loss: 0.2985 - val_accuracy: 0.8820 - val_loss: 0.3508 - learning_rate: 2.5000e-04
# Epoch 36/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8906 - loss: 0.3902 - val_accuracy: 0.8820 - val_loss: 0.3508 - learning_rate: 2.5000e-04
# Epoch 37/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8966 - loss: 0.2921 - val_accuracy: 0.8773 - val_loss: 0.3860 - learning_rate: 2.5000e-04
# Epoch 38/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8281 - loss: 0.3683 - val_accuracy: 0.8770 - val_loss: 0.3864 - learning_rate: 2.5000e-04
# Epoch 39/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8984 - loss: 0.2941 - val_accuracy: 0.8795 - val_loss: 0.3691 - learning_rate: 2.5000e-04
# Epoch 40/50
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9062 - loss: 0.1856
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9062 - loss: 0.1856 - val_accuracy: 0.8802 - val_loss: 0.3678 - learning_rate: 2.5000e-04
# Epoch 41/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9035 - loss: 0.2788 - val_accuracy: 0.8841 - val_loss: 0.3539 - learning_rate: 1.2500e-04
# Epoch 42/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9062 - loss: 0.2840 - val_accuracy: 0.8847 - val_loss: 0.3540 - learning_rate: 1.2500e-04
# Epoch 43/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9106 - loss: 0.2673 - val_accuracy: 0.8838 - val_loss: 0.3539 - learning_rate: 1.2500e-04
# Epoch 44/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9062 - loss: 0.2582 - val_accuracy: 0.8842 - val_loss: 0.3543 - learning_rate: 1.2500e-04
# Epoch 45/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9097 - loss: 0.2650 - val_accuracy: 0.8910 - val_loss: 0.3320 - learning_rate: 1.2500e-04
# Epoch 46/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7656 - loss: 0.7740 - val_accuracy: 0.8909 - val_loss: 0.3310 - learning_rate: 1.2500e-04
# Epoch 47/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 45ms/step - accuracy: 0.9104 - loss: 0.2566 - val_accuracy: 0.8819 - val_loss: 0.3668 - learning_rate: 1.2500e-04
# Epoch 48/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9062 - loss: 0.2083 - val_accuracy: 0.8820 - val_loss: 0.3664 - learning_rate: 1.2500e-04
# Epoch 49/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 38s 44ms/step - accuracy: 0.9101 - loss: 0.2570 - val_accuracy: 0.8840 - val_loss: 0.3475 - learning_rate: 1.2500e-04
# Epoch 50/50
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - accuracy: 0.9062 - loss: 0.2212
# Epoch 50: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9062 - loss: 0.2212 - val_accuracy: 0.8839 - val_loss: 0.3474 - learning_rate: 1.2500e-04

# %% [markdown]
# 4. **Evaluation**

# %%
model.evaluate(x_test, y_test, batch_size=1000)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.8901 - loss: 0.3359
# [0.3320133686065674, 0.890999972820282]

# %% [markdown]
# **5.Viewing predictions on the test set using the predict method**

# %%
CLASSES = np.array(
    [
        "airplane",
        "automobile",
        "bird",
        "cat",
        "deer",
        "dog",
        "frog",
        "horse",
        "ship",
        "truck",
    ]
)

preds = model.predict(x_test)
preds_single = CLASSES[np.argmax(preds, axis=-1)]
actual_single = CLASSES[np.argmax(y_test, axis=-1)]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %% [markdown]
# 6. **Displaying predictions of the CNN against the actual labels**

# %%
import matplotlib.pyplot as plt

n_to_show = 10
indices = np.random.choice(range(len(x_test)), n_to_show)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i, idx in enumerate(indices):
    img = x_test[idx]
    ax = fig.add_subplot(1, n_to_show, i + 1)
    ax.axis("off")
    ax.text(
        0.5,
        -0.35,
        "pred = " + str(preds_single[idx]),
        fontsize=10,
        ha="center",
        transform=ax.transAxes,
    )
    ax.text(
        0.5,
        -0.7,
        "act = " + str(actual_single[idx]),
        fontsize=10,
        ha="center",
        transform=ax.transAxes,
    )
    ax.imshow(img)
